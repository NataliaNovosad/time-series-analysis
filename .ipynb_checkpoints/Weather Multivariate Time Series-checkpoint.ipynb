# %%
import pandas as pd
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss
import re
import matplotlib.pyplot as plt
import numpy as np

from statsmodels.tsa.vector_ar.var_model import VAR
from statsmodels.tsa.statespace.varmax import VARMAX
from statsmodels.tsa.vector_ar.vecm import coint_johansen
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import MinMaxScaler

# %%
city = "San Francisco"
num = 410
split_point = 10 # do not use lot of test data, or else it will come a constant
split_point_train = 400
data = pd.DataFrame([])

humidity = pd.read_csv("time-series-datasets/historical-hourly-weather-data/humidity.csv")
data['humidity'] = humidity[city][:num]
data["datetime"] = humidity["datetime"][:num]
pressure = pd.read_csv("time-series-datasets/historical-hourly-weather-data/pressure.csv")
data['pressure'] = pressure[city][:num]
temperature = pd.read_csv("time-series-datasets/historical-hourly-weather-data/temperature.csv")
data['temperature'] = temperature[city][:num]
wind_speed = pd.read_csv("time-series-datasets/historical-hourly-weather-data/wind_speed.csv")
data['wind_speed'] = wind_speed[city][:num]

# %%
print(data.shape)
data = data.dropna(how = "any")
print(data.shape)
# Out:
# (410, 5)
# (409, 5)

# %%
data.describe()
# Out:
#          humidity     pressure  temperature  wind_speed
# count  409.000000   409.000000   409.000000  409.000000
# mean    71.088020  1015.789731   290.311974    3.095355
# std     16.532857     4.515745     4.269038    2.466084
# min     11.000000  1000.000000   283.050000    0.000000
# 25%     63.000000  1013.000000   287.080000    1.000000
# 50%     72.000000  1016.000000   289.370000    3.000000
# 75%     82.000000  1019.000000   293.020000    5.000000
# max    100.000000  1026.000000   304.860000   12.000000

# %%
date = pd.to_datetime(data.datetime, format = "%Y-%m-%d %H:%M")
data.index = date
data = data.drop(["datetime"], axis = 1)
data.head()
# Out:
#                      humidity  pressure  temperature  wind_speed
# datetime
# 2012-10-01 13:00:00      88.0    1009.0   289.480000         2.0
# 2012-10-01 14:00:00      87.0    1009.0   289.474993         2.0
# 2012-10-01 15:00:00      86.0    1009.0   289.460618         2.0
# 2012-10-01 16:00:00      85.0    1009.0   289.446243         2.0
# 2012-10-01 17:00:00      84.0    1009.0   289.431869         2.0

# %%
test = data[split_point_train:]
train = data[:split_point_train]

# %%
train.shape, test.shape
# Out:
# ((400, 4), (9, 4))

# %%
data = data.astype(float)

for cl in data.columns:
    if cl == "description":
        plt.figure(figsize = (20,5))
        descr = train.groupby(["description"]).count()["humidity"]
        good = descr[descr >= 2000]
        bed = descr[descr < 2000]
        good["other"] = sum(bed)
        plt.bar(good.index, good)
        continue
    plt.figure(figsize = (20,5))
    #plt.scatter(data.index, data[cl])
    train[cl].plot(title = cl)
    plt.show()

# %%
import seaborn as sns
corr_data = data.corr()
sns.heatmap(corr_data)

# %% [markdown]
# # Check the stationarity
#
# For this we have to find **eigenvalues** of matrix Ф. To learn more how do we find the matrix Ф here: https://www.analyticsvidhya.com/blog/2018/09/multivariate-time-series-guide-forecasting-modeling-python-codes/
#
# The idea is to conduct **Johansen’s test**, that will give us the eigenvalues.
#
# 1) eigenvalues < 1 => **stationary**
#
# 2) eigenvalues > 1 => non-stationary

# %%
coint_johansen(data,-1,1).eig
# Out:
# array([1.43717725e-01, 1.14815629e-01, 7.96832209e-02, 1.08180163e-05])

# %% [markdown]
# ## Apply VAR model

# %%
model = VAR(endog = data)
model_fit = model.fit(maxlags = 14) ### maxlags - the order of VAR process == p
# Out:
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:191: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   start=index[0], end=index[-1], freq=freq)

# %%
preds_var = model_fit.forecast(train.values.tolist(), steps = len(test)) ### steps - how much data forward you want to predict 

preds_var = preds_var.transpose()

for i, cl in enumerate(data.columns):
    print('mse value for ', cl, ' is : ', mean_squared_error(preds_var[i], test[cl]))
    print('rmse value for ', cl, ' is : ', np.sqrt(mean_squared_error(preds_var[i], test[cl])))
    print('mae value for ', cl, ' is : ', mean_absolute_error(preds_var[i], test[cl]))
# Out:
# mse value for  humidity  is :  18.584022948723014
# rmse value for  humidity  is :  4.3109190375977855
# mae value for  humidity  is :  3.311426678487188
# mse value for  pressure  is :  1.0523652758096083
# rmse value for  pressure  is :  1.0258485637800583
# mae value for  pressure  is :  0.9188356033512642
# mse value for  temperature  is :  3.560791189401359
# rmse value for  temperature  is :  1.8870058795354505
# mae value for  temperature  is :  1.7407065275101559
# mse value for  wind_speed  is :  2.226097931950585
# rmse value for  wind_speed  is :  1.49201137125378
# mae value for  wind_speed  is :  1.3568541072462068

# %%
model_fit.plot_forecast(len(test))
plt.show()

# %%
for i, col in enumerate(test.columns):
    plt.plot(range(len(preds_var[i])), preds_var[i], label = "predict")
    plt.plot(range(len(test[col])), test[col], label = "actual")
    plt.legend()
    plt.title(col)
    plt.show()

# %%
# find the best maxlags parameter
res = dict()
for i in range(1,20):
    model_fit = model.fit(maxlags = i)
    preds = model_fit.forecast(train.values.tolist(), steps = len(test))
    preds = preds.transpose()
    error = 0
    for j, cl in enumerate(train.columns):
        error = error + np.sqrt(mean_squared_error(preds[j], test[cl]))
    res[i] = error

# %%
min(res, key = res.get) # best order for model
# Out:
# 14

# %% [markdown]
# ## Apply VARMAX model

# %%
model = VARMAX(endog = train, order = (11,0))
model_fit = model.fit(maxlags = 11)
# Out:
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:191: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   start=index[0], end=index[-1], freq=freq)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\representation.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return matrix[[slice(None)]*(matrix.ndim-1) + [0]]

# %%
preds_varmax = model_fit.forecast(steps = len(test)) ### steps - how much data forward you want to predict 

preds_varmax = preds_varmax.transpose()

for i, cl in enumerate(train.columns):
    print('mse value for ', cl, ' is : ', mean_squared_error(preds_varmax.loc[cl], test[cl]))
    print('rmse value for ', cl, ' is : ', np.sqrt(mean_squared_error(preds_varmax.loc[cl], test[cl])))
    print('mae value for ', cl, ' is : ', mean_absolute_error(preds_varmax.loc[cl], test[cl]))
# Out:
# mse value for  humidity  is :  91.49173354452512
# rmse value for  humidity  is :  9.565131130545211
# mae value for  humidity  is :  7.497470932754918
# mse value for  pressure  is :  2.553143288027858
# rmse value for  pressure  is :  1.5978558408153902
# mae value for  pressure  is :  1.47654411536482
# mse value for  temperature  is :  6.473489989917939
# rmse value for  temperature  is :  2.5443054042150557
# mae value for  temperature  is :  2.239026671835657
# mse value for  wind_speed  is :  3.201872482750078
# rmse value for  wind_speed  is :  1.7893776802983985
# mae value for  wind_speed  is :  1.6915881493261422
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:320: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   freq=base_index.freq)

# %%
for i, col in enumerate(test.columns):
    plt.plot(range(len(preds_varmax.loc[col])),preds_varmax.loc[col], label = "predict varmax")
    plt.plot(range(len(preds_var[i])), preds_var[i], label = "predict var")
    plt.plot(range(len(test[col])), test[col], label = "actual")
    plt.legend()
    plt.title(col)
    plt.show()

# %%
# find the best p , q parameter
res = dict()
for q in range(0,10):
    for p in [7,10,11]:
        model = VARMAX(endog = train, order = (p,q))
        model_fit = model.fit(maxlags = p)
        preds = model_fit.forecast(steps = len(test))
        preds = preds.transpose()
        error = 0
        for j, cl in enumerate(test.columns):
            error = error + np.sqrt(mean_squared_error(preds.loc[cl], test[cl]))
        res[tuple([p,q])] = error
        print("{},{} is done, error = {}".format(p,q, error))
# Out:
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:320: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   freq=base_index.freq)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:191: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   start=index[0], end=index[-1], freq=freq)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\representation.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return matrix[[slice(None)]*(matrix.ndim-1) + [0]]
# 7,0 is done, error = 15.611687428938247
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:320: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   freq=base_index.freq)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:191: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   start=index[0], end=index[-1], freq=freq)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\representation.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return matrix[[slice(None)]*(matrix.ndim-1) + [0]]
# 10,0 is done, error = 14.940941319945608
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:320: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   freq=base_index.freq)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:152: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:191: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   start=index[0], end=index[-1], freq=freq)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\representation.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return matrix[[slice(None)]*(matrix.ndim-1) + [0]]
# 11,0 is done, error = 14.85872805924382
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:320: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   freq=base_index.freq)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:152: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:152: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:191: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   start=index[0], end=index[-1], freq=freq)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\representation.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return matrix[[slice(None)]*(matrix.ndim-1) + [0]]
# 7,1 is done, error = 15.856361232765108
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:320: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   freq=base_index.freq)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:152: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:152: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:191: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   start=index[0], end=index[-1], freq=freq)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\representation.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return matrix[[slice(None)]*(matrix.ndim-1) + [0]]
# 10,1 is done, error = 15.047676353736469
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:320: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   freq=base_index.freq)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:152: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:152: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:191: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   start=index[0], end=index[-1], freq=freq)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\representation.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return matrix[[slice(None)]*(matrix.ndim-1) + [0]]
# 11,1 is done, error = 14.961114719975523
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:320: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   freq=base_index.freq)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:152: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:152: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:191: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   start=index[0], end=index[-1], freq=freq)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\representation.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return matrix[[slice(None)]*(matrix.ndim-1) + [0]]
# 7,2 is done, error = 15.778987819534835
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:320: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   freq=base_index.freq)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:152: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:152: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:191: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   start=index[0], end=index[-1], freq=freq)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\representation.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return matrix[[slice(None)]*(matrix.ndim-1) + [0]]
# 10,2 is done, error = 15.35941740098492
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:320: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   freq=base_index.freq)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:152: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:152: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:191: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   start=index[0], end=index[-1], freq=freq)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\representation.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return matrix[[slice(None)]*(matrix.ndim-1) + [0]]
# 11,2 is done, error = 15.0793045613662
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:320: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   freq=base_index.freq)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:152: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\varmax.py:152: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   EstimationWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:191: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   start=index[0], end=index[-1], freq=freq)
# C:\Users\Natalia Novosad\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\representation.py:375: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return matrix[[slice(None)]*(matrix.ndim-1) + [0]]
# 7,3 is done, error = 17.190165468388873
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-243-03caca33bd09> in <module>
#       4     for p in [7,10,11]:
#       5         model = VARMAX(endog = train, order = (p,q))
# ----> 6         model_fit = model.fit(maxlags = p)
#       7         preds = model_fit.forecast(steps = len(test))
#       8         preds = preds.transpose()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in fit(self, start_params, transformed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, **kwargs)
#     467                                            full_output=full_output,
#     468                                            disp=disp, callback=callback,
# --> 469                                            skip_hessian=True, **kwargs)
#     470
#     471         # Just return the fitted parameters if requested
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     464                                                        callback=callback,
#     465                                                        retall=retall,
# --> 466                                                        full_output=full_output)
#     467
#     468         # NOTE: this is for fit_regularized and should be generalized
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     189                             disp=disp, maxiter=maxiter, callback=callback,
#     190                             retall=retall, full_output=full_output,
# --> 191                             hess=hessian)
#     192
#     193         optim_settings = {'optimizer': method, 'start_params': start_params,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     408                                      callback=callback, args=fargs,
#     409                                      bounds=bounds, disp=disp,
# --> 410                                      **extra_kwargs)
#     411
#     412     if full_output:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py in func_and_grad(x)
#     279         def func_and_grad(x):
#     280             f = fun(x, *args)
# --> 281             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     282             return f, g
#     283     else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py in _approx_fprime_helper(xk, f, epsilon, args, f0)
#     668         ei[k] = 1.0
#     669         d = epsilon * ei
# --> 670         grad[k] = (f(*((xk + d,) + args)) - f0) / d[k]
#     671         ei[k] = 0.0
#     672     return grad
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     298     def function_wrapper(*wrapper_args):
#     299         ncalls[0] += 1
# --> 300         return function(*(wrapper_args + args))
#     301
#     302     return ncalls, function_wrapper
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\model.py in f(params, *args)
#     438
#     439         def f(params, *args):
# --> 440             return -self.loglike(params, *args) / nobs
#     441
#     442         if method == 'newton':
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in loglike(self, params, *args, **kwargs)
#     644             kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#     645
# --> 646         loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     647
#     648         # Koopman, Shephard, and Doornik recommend maximizing the average
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py in loglike(self, **kwargs)
#     823                                ' MEMORY_NO_LIKELIHOOD option is selected.')
#     824         kwargs['conserve_memory'] = MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD
# --> 825         kfilter = self._filter(**kwargs)
#     826         loglikelihood_burn = kwargs.get('loglikelihood_burn',
#     827                                         self.loglikelihood_burn)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py in _filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     749         # Run the filter
#     750         kfilter()
# --> 751         tmp = np.array(kfilter.loglikelihood)
#     752         tmp2 = np.array(kfilter.predicted_state)
#     753
#
# KeyboardInterrupt:

# %%
min(res, key = res.get) # best p, q for model
# Out:
# (11, 0)

# %% [markdown]
# # Keras LSTM

# %%
import keras
from keras import Sequential
from keras.layers import LSTM 
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Transport data for NN

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = data.shape[1]
    cols, names = list(), list()
    df = pd.DataFrame(data)
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [j + "(t-{})".format(i) for j in data.columns]
    # forecast sequence (t, t+1, ... t+n) 
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [j + "(t)" for j in data.columns]
        else:
            names += [j + "(t+{})".format(i) for j in data.columns]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True) #any
    return agg

# %%
supervised = series_to_supervised(data,1,1)
supervised = supervised.drop(["humidity(t)","pressure(t)", "wind_speed(t)"], axis = 1)
scaler = MinMaxScaler(feature_range=(0, 1))
supervised_scaled = scaler.fit_transform(supervised)

supervised_scaled = pd.DataFrame(supervised_scaled, columns = supervised.columns)

# %%
supervised_scaled.head()
# Out:
#    humidity(t-1)  pressure(t-1)  temperature(t-1)  wind_speed(t-1)  \
# 0       0.865169       0.346154          0.294819         0.166667
# 1       0.853933       0.346154          0.294589         0.166667
# 2       0.842697       0.346154          0.293930         0.166667
# 3       0.831461       0.346154          0.293271         0.166667
# 4       0.820225       0.346154          0.292612         0.166667
#
#    temperature(t)
# 0        0.294589
# 1        0.293930
# 2        0.293271
# 3        0.292612
# 4        0.291953

# %%
test = supervised_scaled[split_point_train-1:]
train = supervised_scaled[:split_point_train-1]

train.shape, test.shape
# Out:
# ((399, 5), (9, 5))

# %%
features = list(supervised_scaled.columns)
features.remove("temperature(t)")
train_X, train_y = train[features].values, train[["temperature(t)"]].values
test_X, test_y = test[features].values, test[["temperature(t)"]].values

### neeeded for NN
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %% [markdown]
# ### Create NN

# %%
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adadelta')

# %%
# fit network
history = model.fit(train_X, train_y, epochs=150, batch_size=72, validation_data=(test_X, test_y), verbose=1, shuffle=False)
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Train on 399 samples, validate on 9 samples
# Epoch 1/150
# 399/399 [==============================] - 1s 2ms/step - loss: 0.3279 - val_loss: 0.1748
# Epoch 2/150
# 399/399 [==============================] - 0s 21us/step - loss: 0.2528 - val_loss: 0.1013
# Epoch 3/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.1986 - val_loss: 0.0639
# Epoch 4/150
# 399/399 [==============================] - 0s 22us/step - loss: 0.1758 - val_loss: 0.0506
# Epoch 5/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.1638 - val_loss: 0.0449
# Epoch 6/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.1565 - val_loss: 0.0425
# Epoch 7/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.1526 - val_loss: 0.0439
# Epoch 8/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.1496 - val_loss: 0.0440
# Epoch 9/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.1472 - val_loss: 0.0435
# Epoch 10/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.1447 - val_loss: 0.0425
# Epoch 11/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.1422 - val_loss: 0.0418
# Epoch 12/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.1396 - val_loss: 0.0408
# Epoch 13/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.1369 - val_loss: 0.0401
# Epoch 14/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.1343 - val_loss: 0.0380
# Epoch 15/150
# 399/399 [==============================] - 0s 198us/step - loss: 0.1315 - val_loss: 0.0359
# Epoch 16/150
# 399/399 [==============================] - 0s 66us/step - loss: 0.1288 - val_loss: 0.0359
# Epoch 17/150
# 399/399 [==============================] - 0s 40us/step - loss: 0.1260 - val_loss: 0.0341
# Epoch 18/150
# 399/399 [==============================] - 0s 40us/step - loss: 0.1231 - val_loss: 0.0320
# Epoch 19/150
# 399/399 [==============================] - 0s 40us/step - loss: 0.1202 - val_loss: 0.0309
# Epoch 20/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.1174 - val_loss: 0.0302
# Epoch 21/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.1145 - val_loss: 0.0306
# Epoch 22/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.1116 - val_loss: 0.0302
# Epoch 23/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.1087 - val_loss: 0.0297
# Epoch 24/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.1057 - val_loss: 0.0282
# Epoch 25/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.1026 - val_loss: 0.0277
# Epoch 26/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0994 - val_loss: 0.0267
# Epoch 27/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0962 - val_loss: 0.0251
# Epoch 28/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0929 - val_loss: 0.0241
# Epoch 29/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0898 - val_loss: 0.0231
# Epoch 30/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0867 - val_loss: 0.0221
# Epoch 31/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0831 - val_loss: 0.0201
# Epoch 32/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0800 - val_loss: 0.0207
# Epoch 33/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0764 - val_loss: 0.0231
# Epoch 34/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0731 - val_loss: 0.0250
# Epoch 35/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0703 - val_loss: 0.0256
# Epoch 36/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0674 - val_loss: 0.0281
# Epoch 37/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0646 - val_loss: 0.0317
# Epoch 38/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0621 - val_loss: 0.0351
# Epoch 39/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0588 - val_loss: 0.0379
# Epoch 40/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0547 - val_loss: 0.0435
# Epoch 41/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0514 - val_loss: 0.0440
# Epoch 42/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0493 - val_loss: 0.0440
# Epoch 43/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0477 - val_loss: 0.0462
# Epoch 44/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0460 - val_loss: 0.0508
# Epoch 45/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0449 - val_loss: 0.0545
# Epoch 46/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0439 - val_loss: 0.0578
# Epoch 47/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0435 - val_loss: 0.0601
# Epoch 48/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0427 - val_loss: 0.0615
# Epoch 49/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0420 - val_loss: 0.0632
# Epoch 50/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0417 - val_loss: 0.0662
# Epoch 51/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0419 - val_loss: 0.0665
# Epoch 52/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0417 - val_loss: 0.0648
# Epoch 53/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0412 - val_loss: 0.0646
# Epoch 54/150
# 399/399 [==============================] - 0s 40us/step - loss: 0.0410 - val_loss: 0.0627
# Epoch 55/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0409 - val_loss: 0.0586
# Epoch 56/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0403 - val_loss: 0.0604
# Epoch 57/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0398 - val_loss: 0.0625
# Epoch 58/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0401 - val_loss: 0.0598
# Epoch 59/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0399 - val_loss: 0.0582
# Epoch 60/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0395 - val_loss: 0.0598
# Epoch 61/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0390 - val_loss: 0.0618
# Epoch 62/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0390 - val_loss: 0.0625
# Epoch 63/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0389 - val_loss: 0.0618
# Epoch 64/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0385 - val_loss: 0.0629
# Epoch 65/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0386 - val_loss: 0.0625
# Epoch 66/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0385 - val_loss: 0.0621
# Epoch 67/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0386 - val_loss: 0.0610
# Epoch 68/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0383 - val_loss: 0.0605
# Epoch 69/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0383 - val_loss: 0.0610
# Epoch 70/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0382 - val_loss: 0.0614
# Epoch 71/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0383 - val_loss: 0.0605
# Epoch 72/150
# 399/399 [==============================] - 0s 40us/step - loss: 0.0381 - val_loss: 0.0610
# Epoch 73/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0380 - val_loss: 0.0616
# Epoch 74/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0382 - val_loss: 0.0606
# Epoch 75/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0378 - val_loss: 0.0613
# Epoch 76/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0381 - val_loss: 0.0615
# Epoch 77/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0379 - val_loss: 0.0608
# Epoch 78/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0381 - val_loss: 0.0620
# Epoch 79/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0378 - val_loss: 0.0614
# Epoch 80/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0383 - val_loss: 0.0600
# Epoch 81/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0373 - val_loss: 0.0594
# Epoch 82/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0377 - val_loss: 0.0608
# Epoch 83/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0378 - val_loss: 0.0587
# Epoch 84/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0374 - val_loss: 0.0580
# Epoch 85/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0375 - val_loss: 0.0583
# Epoch 86/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0374 - val_loss: 0.0585
# Epoch 87/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0371 - val_loss: 0.0589
# Epoch 88/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0373 - val_loss: 0.0581
# Epoch 89/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0369 - val_loss: 0.0577
# Epoch 90/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0371 - val_loss: 0.0567
# Epoch 91/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0368 - val_loss: 0.0572
# Epoch 92/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0371 - val_loss: 0.0600
# Epoch 93/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0376 - val_loss: 0.0586
# Epoch 94/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0365 - val_loss: 0.0555
# Epoch 95/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0366 - val_loss: 0.0571
# Epoch 96/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0362 - val_loss: 0.0567
# Epoch 97/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0361 - val_loss: 0.0575
# Epoch 98/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0369 - val_loss: 0.0561
# Epoch 99/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0359 - val_loss: 0.0537
# Epoch 100/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0364 - val_loss: 0.0565
# Epoch 101/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0360 - val_loss: 0.0548
# Epoch 102/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0356 - val_loss: 0.0547
# Epoch 103/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0355 - val_loss: 0.0545
# Epoch 104/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0356 - val_loss: 0.0563
# Epoch 105/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0362 - val_loss: 0.0537
# Epoch 106/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0364 - val_loss: 0.0534
# Epoch 107/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0353 - val_loss: 0.0522
# Epoch 108/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0361 - val_loss: 0.0535
# Epoch 109/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0361 - val_loss: 0.0533
# Epoch 110/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0353 - val_loss: 0.0529
# Epoch 111/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0362 - val_loss: 0.0530
# Epoch 112/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0361 - val_loss: 0.0531
# Epoch 113/150
# 399/399 [==============================] - 0s 40us/step - loss: 0.0353 - val_loss: 0.0512
# Epoch 114/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0356 - val_loss: 0.0528
# Epoch 115/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0353 - val_loss: 0.0518
# Epoch 116/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0358 - val_loss: 0.0511
# Epoch 117/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0350 - val_loss: 0.0507
# Epoch 118/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0357 - val_loss: 0.0491
# Epoch 119/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0349 - val_loss: 0.0468
# Epoch 120/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0353 - val_loss: 0.0531
# Epoch 121/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0353 - val_loss: 0.0490
# Epoch 122/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0351 - val_loss: 0.0516
# Epoch 123/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0355 - val_loss: 0.0496
# Epoch 124/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0347 - val_loss: 0.0451
# Epoch 125/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0350 - val_loss: 0.0442
# Epoch 126/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0350 - val_loss: 0.0468
# Epoch 127/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0348 - val_loss: 0.0489
# Epoch 128/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0349 - val_loss: 0.0474
# Epoch 129/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0348 - val_loss: 0.0448
# Epoch 130/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0350 - val_loss: 0.0460
# Epoch 131/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0347 - val_loss: 0.0471
# Epoch 132/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0346 - val_loss: 0.0470
# Epoch 133/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0345 - val_loss: 0.0423
# Epoch 134/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0345 - val_loss: 0.0428
# Epoch 135/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0349 - val_loss: 0.0440
# Epoch 136/150
# 399/399 [==============================] - ETA: 0s - loss: 0.041 - 0s 20us/step - loss: 0.0344 - val_loss: 0.0456
# Epoch 137/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0345 - val_loss: 0.0434
# Epoch 138/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0344 - val_loss: 0.0449
# Epoch 139/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0345 - val_loss: 0.0451
# Epoch 140/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0347 - val_loss: 0.0452
# Epoch 141/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0346 - val_loss: 0.0429
# Epoch 142/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0343 - val_loss: 0.0438
# Epoch 143/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0344 - val_loss: 0.0439
# Epoch 144/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0340 - val_loss: 0.0438
# Epoch 145/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0344 - val_loss: 0.0442
# Epoch 146/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0347 - val_loss: 0.0450
# Epoch 147/150
# 399/399 [==============================] - 0s 30us/step - loss: 0.0348 - val_loss: 0.0448
# Epoch 148/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0348 - val_loss: 0.0434
# Epoch 149/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0344 - val_loss: 0.0430
# Epoch 150/150
# 399/399 [==============================] - 0s 20us/step - loss: 0.0347 - val_loss: 0.0422

# %%
# make a prediction
preds = model.predict(test_X)

test_Y = pd.DataFrame(test, copy = True)
test_Y["temperature(t)"] = preds
test_transformed = scaler.inverse_transform(test_Y)
preds = test_transformed[:,-1]

test_transformed = scaler.inverse_transform(test)
real = test_transformed[:,-1]

# calculate RMSE
rmse = np.sqrt(mean_squared_error(real, preds))
print('Test RMSE for LSTM: ', rmse)
print('rmse value for VARMAX is : ', np.sqrt(mean_squared_error(preds_varmax.loc["temperature"], real)))
print('rmse value for VAR is : ', np.sqrt(mean_squared_error(preds_var[2], real)))
# Out:
# Test RMSE for LSTM:  0.9426917203413263
# rmse value for VARMAX is :  2.5443054042150557
# rmse value for VAR is :  1.8870058795354505

# %%
plt.plot(real, label = "real")
plt.plot(preds, label = "LSTM")
plt.plot(range(len(preds_varmax.loc["temperature"])),preds_varmax.loc["temperature"], label = "predict varmax")
plt.plot(range(len(preds_var[2])), preds_var[2], label = "predict var")
plt.legend()
